# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
df = pd.read_excel('C:/Users/lenovo/Desktop/mavoix_ml_sample_dataset.xlsx')

# %%
df.shape
# Out:
# (392, 24)

# %%
df.head()
# Out:
#   Application_ID Current City  Python (out of 3)  R Programming (out of 3)  \
# 0         ML0001    Bangalore                  0                         2
# 1         ML0002    Bangalore                  2                         0
# 2         ML0003    Bangalore                  3                         0
# 3         ML0004    Bangalore                  2                         0
# 4         ML0005    Bangalore                  2                         0
#
#    Deep Learning (out of 3)  PHP (out of 3)  MySQL (out of 3)  \
# 0                         0               2                 0
# 1                         0               2                 2
# 2                         1               2                 2
# 3                         2               1                 0
# 4                         0               2                 0
#
#    HTML (out of 3)  CSS (out of 3)  JavaScript (out of 3)  ...  \
# 0                2               3                      2  ...
# ...

# %%
df.columns
# Out:
# Index(['Application_ID', 'Current City', 'Python (out of 3)',
#        'R Programming (out of 3)', 'Deep Learning (out of 3)',
#        'PHP (out of 3)', 'MySQL (out of 3)', 'HTML (out of 3)',
#        'CSS (out of 3)', 'JavaScript (out of 3)', 'Unnamed: 10',
#        'AJAX (out of 3)', 'Bootstrap (out of 3)', 'MongoDB (out of 3)',
#        'Node.js (out of 3)', 'ReactJS (out of 3)', 'Other skills', 'Degree',
#        'Stream', 'Current Year Of Graduation', 'Performance_PG',
#        'Performance_UG', 'Performance_12', 'Performance_10'],
#       dtype='object')

# %%
df.describe()
# Out:
#        Python (out of 3)  R Programming (out of 3)  Deep Learning (out of 3)  \
# count         392.000000                392.000000                392.000000
# mean            1.375000                  0.566327                  0.461735
# std             0.975237                  0.905052                  0.842336
# min             0.000000                  0.000000                  0.000000
# 25%             0.000000                  0.000000                  0.000000
# 50%             2.000000                  0.000000                  0.000000
# 75%             2.000000                  1.000000                  1.000000
# max             3.000000                  3.000000                  3.000000
#
#        PHP (out of 3)  MySQL (out of 3)  HTML (out of 3)  CSS (out of 3)  \
# count      392.000000        392.000000       392.000000      392.000000
# mean         0.612245          0.403061         1.346939        1.045918
# ...

# %%
df.describe(include='object')
# Out:
#        Application_ID Current City                              Other skills  \
# count             392          392                                       378
# unique            392           63                                       313
# top            ML0179    Bangalore  Data Analytics, Machine Learning, Python
# freq                1          214                                         4
#
#                                  Degree             Stream Performance_PG  \
# count                               380                374            103
# unique                               31                 78             66
# top     Bachelor of Technology (B.Tech)  Computer  Science        7.60/10
# freq                                110                 64              5
#
#        Performance_UG Performance_12 Performance_10
# count             338            229            215
# unique            173            143            108
# ...

# %% [markdown]
# # Most of the applicants are from Bangalore, most of the applicants are from B.Tech background and most of the applicants have computer science has their stream.

# %%
df.dtypes
# Out:
# Application_ID                 object
# Current City                   object
# Python (out of 3)               int64
# R Programming (out of 3)        int64
# Deep Learning (out of 3)        int64
# PHP (out of 3)                  int64
# MySQL (out of 3)                int64
# HTML (out of 3)                 int64
# CSS (out of 3)                  int64
# JavaScript (out of 3)           int64
# Unnamed: 10                   float64
# AJAX (out of 3)                 int64
# Bootstrap (out of 3)            int64
# MongoDB (out of 3)              int64
# Node.js (out of 3)              int64
# ReactJS (out of 3)              int64
# Other skills                   object
# Degree                         object
# Stream                         object
# Current Year Of Graduation      int64
# Performance_PG                 object
# Performance_UG                 object
# Performance_12                 object
# Performance_10                 object
# dtype: object

# %%
df.isnull().sum()
# Out:
# Application_ID                  0
# Current City                    0
# Python (out of 3)               0
# R Programming (out of 3)        0
# Deep Learning (out of 3)        0
# PHP (out of 3)                  0
# MySQL (out of 3)                0
# HTML (out of 3)                 0
# CSS (out of 3)                  0
# JavaScript (out of 3)           0
# Unnamed: 10                   392
# AJAX (out of 3)                 0
# Bootstrap (out of 3)            0
# MongoDB (out of 3)              0
# Node.js (out of 3)              0
# ReactJS (out of 3)              0
# Other skills                   14
# Degree                         12
# Stream                         18
# Current Year Of Graduation      0
# Performance_PG                289
# Performance_UG                 54
# Performance_12                163
# Performance_10                177
# dtype: int64

# %% [markdown]
# # Among 392 rows we can see lot of null values in performance pg, most probably most of the applicants haven't completed pg. But we have null values in ug, 12th and 10th as well it implies many of the applicants didn't provide the deatails of their marks. Since unnamed 10 feature is of no use we can drop that directly.

# %%
pd.set_option('display.max_columns',None)

# %%
df.head(3)
# Out:
#   Application_ID Current City  Python (out of 3)  R Programming (out of 3)  \
# 0         ML0001    Bangalore                  0                         2
# 1         ML0002    Bangalore                  2                         0
# 2         ML0003    Bangalore                  3                         0
#
#    Deep Learning (out of 3)  PHP (out of 3)  MySQL (out of 3)  \
# 0                         0               2                 0
# 1                         0               2                 2
# 2                         1               2                 2
#
#    HTML (out of 3)  CSS (out of 3)  JavaScript (out of 3)  Unnamed: 10  \
# 0                2               3                      2          NaN
# 1                2               2                      2          NaN
# 2                2               0                      2          NaN
#
#    AJAX (out of 3)  Bootstrap (out of 3)  MongoDB (out of 3)  \
# 0                0                     2                   0
# ...

# %%
df['Degree'].value_counts()
# Out:
# Bachelor of Technology (B.Tech)                          110
# Bachelor of Engineering (B.E)                             84
# Master of Computer Applications (MCA)                     70
# B.Tech (Hons.)                                            25
# Master of Technology (M.Tech)                             19
# Master of Science (M.Sc)                                  14
# Bachelor of Computer Applications (BCA)                   10
# Post Graduate Programme (PGP)                              8
# Integrated M.Sc.                                           5
# PG Diploma in Data Science                                 5
# Bachelor of Science (B.Sc)                                 5
# Integrated B.Tech & M.Tech                                 2
# MBA                                                        2
# Integrated B.Tech                                          2
# Post Graduate Diploma in Management (P.G.D.M.)             2
# ...

# %% [markdown]
# # Most of the applicants either have a degree in engineering or a masters in science.

# %%
df['Other skills'].value_counts().head(20)
# Out:
# Data Analytics, Machine Learning, Python                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         4
# ...

# %%
df['Stream'].value_counts().head(15)
# Out:
# Computer  Science                                      64
# Electronics and Communication                          46
# Computer Science & Engineering                         45
# Computer Application                                   35
# Information Technology                                 20
# Mechanical Engineering                                 15
# computer science                                       11
# Data Science                                           10
# Electronics and Telecommunication Engineering (ETE)     8
# Electrical and Electronics Engineering                  7
# MCA                                                     6
# Mathematics                                             6
# IT                                                      5
# Data Analytics                                          5
# Business Analytics                                      4
# Name: Stream, dtype: int64

# %% [markdown]
# # Most of the applicants are from computer science and electronics background.

# %%
df['Current Year Of Graduation'].value_counts()
# Out:
# 2020    138
# 2019    108
# 2021     35
# 2018     29
# 2017     25
# 2016     18
# 2022     11
# 2015      9
# 2014      5
# 2013      4
# 2012      3
# 2023      2
# 2008      2
# 2007      1
# 2006      1
# 2004      1
# Name: Current Year Of Graduation, dtype: int64

# %% [markdown]
# # Most of the applicants are with less work experience or freshers.

# %%
df.drop('Unnamed: 10',axis=1,inplace=True)

# %%
df.head(1)
# Out:
#   Application_ID Current City  Python (out of 3)  R Programming (out of 3)  \
# 0         ML0001    Bangalore                  0                         2
#
#    Deep Learning (out of 3)  PHP (out of 3)  MySQL (out of 3)  \
# 0                         0               2                 0
#
#    HTML (out of 3)  CSS (out of 3)  JavaScript (out of 3)  AJAX (out of 3)  \
# 0                2               3                      2                0
#
#    Bootstrap (out of 3)  MongoDB (out of 3)  Node.js (out of 3)  \
# 0                     2                   0                   0
#
#    ReactJS (out of 3)   Other skills                      Degree       Stream  \
# 0                   0  R Programming  Bachelor of Science (B.Sc)  Mathematics
#
#    Current Year Of Graduation Performance_PG Performance_UG Performance_12  \
# 0                        2017            NaN            NaN            NaN
#
#   Performance_10
# 0            NaN

# %%
plt.subplots(figsize=(20,7))
sns.boxplot(data=df)

# %%
df.head()
# Out:
#   Application_ID Current City  Python (out of 3)  R Programming (out of 3)  \
# 0         ML0001    Bangalore                  0                         2
# 1         ML0002    Bangalore                  2                         0
# 2         ML0003    Bangalore                  3                         0
# 3         ML0004    Bangalore                  2                         0
# 4         ML0005    Bangalore                  2                         0
#
#    Deep Learning (out of 3)  PHP (out of 3)  MySQL (out of 3)  \
# 0                         0               2                 0
# 1                         0               2                 2
# 2                         1               2                 2
# 3                         2               1                 0
# 4                         0               2                 0
#
#    HTML (out of 3)  CSS (out of 3)  JavaScript (out of 3)  AJAX (out of 3)  \
# ...

# %%
df['Performance_PG'] = df['Performance_PG'].transform(lambda x: x.fillna('No degree'))

# %%
df1 = df['Performance_UG'].str.split('/',expand=True)
df2 = df['Performance_12'].str.split('/',expand=True)
df3 = df['Performance_10'].str.split('/',expand=True)

# %%
df1.drop(1,axis=1,inplace=True)
df2.drop(1,axis=1,inplace=True)
df3.drop(1,axis=1,inplace=True)

# %%
df1 = df1.rename(columns={0:'Performance_UG'})
df2 = df2.rename(columns={0:'Performance_12'})
df3 = df3.rename(columns={0:'Performance_10'})

# %%
scores = pd.concat([df1,df2,df3],axis=1)
scores.head(2)
# Out:
#   Performance_UG Performance_12 Performance_10
# 0            NaN            NaN            NaN
# 1          85.50          92.20          96.60

# %%
df.drop(['Performance_PG','Performance_UG','Performance_12','Performance_10'],axis=1,inplace=True)

# %%
data = pd.concat([df,scores],axis=1)
data.head(2)
# Out:
#   Application_ID Current City  Python (out of 3)  R Programming (out of 3)  \
# 0         ML0001    Bangalore                  0                         2
# 1         ML0002    Bangalore                  2                         0
#
#    Deep Learning (out of 3)  PHP (out of 3)  MySQL (out of 3)  \
# 0                         0               2                 0
# 1                         0               2                 2
#
#    HTML (out of 3)  CSS (out of 3)  JavaScript (out of 3)  AJAX (out of 3)  \
# 0                2               3                      2                0
# 1                2               2                      2                0
#
#    Bootstrap (out of 3)  MongoDB (out of 3)  Node.js (out of 3)  \
# 0                     2                   0                   0
# 1                     0                   0                   0
#
#    ReactJS (out of 3)                                       Other skills  \
# ...

# %%
data['Performance_UG'] = data['Performance_UG'].astype(float)
data['Performance_12'] = data['Performance_12'].astype(float)
data['Performance_10'] = data['Performance_10'].astype(float)

# %%
data['Performance_UG'] = data['Performance_UG'].transform(lambda x : x.fillna(data['Performance_UG'].mean()))
data['Performance_12'] = data['Performance_12'].transform(lambda x : x.fillna(data['Performance_12'].mean()))
data['Performance_10'] = data['Performance_10'].transform(lambda x : x.fillna(data['Performance_10'].mean()))

# %% [markdown]
# # We can either drop the features with many null values but in our case we replaced it with mean because the feature might be important. Imputing the null values depends on the business requirement.

# %%
plt.subplots(figsize=(11,11))
sns.heatmap(data.corr(),square=True,annot=True)

# %% [markdown]
# # There is a lot of multi colenearity among features. Which is not good for a model.

# %% [markdown]
# # There is no target variable so we have to do clustering and identify similar groups to create labels and then we can use that label as a dependent variable, where we can decide to select a candidate or not.

# %% [markdown]
# # The categorical data must be converted to numbers through encoding and since clustering is a distance based technique we do scaling.

# %%
from sklearn.preprocessing import StandardScaler
from sklearn import preprocessing

# %%
std = StandardScaler()

# %%
lable = preprocessing.LabelEncoder()

# %%
data['Other skills'] = data['Other skills'].transform(lambda x: x.fillna('unknown'))
data['Degree'] = data['Degree'].transform(lambda x: x.fillna('unknown'))
data['Stream'] = data['Stream'].transform(lambda x: x.fillna('unknown'))

# %%
df_labled = data.apply(lable.fit_transform)

# %%
df_scaled = std.fit_transform(df_labled)

# %%
df_scaled = pd.DataFrame(df_scaled,columns=data.columns)

# %%
df_scaled.head()
# Out:
#    Application_ID  Current City  Python (out of 3)  R Programming (out of 3)  \
# 0       -1.727638     -0.652202          -1.411716                  1.586103
# 1       -1.718801     -0.652202           0.641689                 -0.626539
# 2       -1.709964     -0.652202           1.668391                 -0.626539
# 3       -1.701127     -0.652202           0.641689                 -0.626539
# 4       -1.692290     -0.652202           0.641689                 -0.626539
#
#    Deep Learning (out of 3)  PHP (out of 3)  MySQL (out of 3)  \
# 0                 -0.548860        1.523959         -0.481824
# 1                 -0.548860        1.523959          1.908998
# 2                  0.639832        1.523959          1.908998
# 3                  1.828524        0.425812         -0.481824
# 4                 -0.548860        1.523959         -0.481824
#
#    HTML (out of 3)  CSS (out of 3)  JavaScript (out of 3)  AJAX (out of 3)  \
# ...

# %%
df_scaled.drop('Application_ID',axis=1,inplace=True)

# %%
sns.pairplot(data=df_scaled)

# %% [markdown]
# # Principal component analysis helps to increase signal to noise ratio and also in feature extraction and dimensionality reduction.

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA()
pc = pca.fit_transform(df_scaled)

# %%
features = range(pca.n_components_)
plt.bar(features, pca.explained_variance_ratio_, color='black')
plt.xlabel('PCA features')
plt.ylabel('variance %')
plt.xticks(features)
# Out:
# ([<matplotlib.axis.XTick at 0x23740d37c88>,
# ...
#  <a list of 21 Text xticklabel objects>)

# %% [markdown]
# # We can do feature selection by taking principal components which covers 90% of the data.

# %%
pca = PCA(n_components=13)
pc = pca.fit_transform(df_scaled)

# %%
features = range(pca.n_components_)
plt.bar(features, pca.explained_variance_ratio_, color='black')
plt.xlabel('PCA features')
plt.ylabel('variance %')
plt.xticks(features)
# Out:
# ([<matplotlib.axis.XTick at 0x2374948fa88>,
# ...
#  <a list of 13 Text xticklabel objects>)

# %%
PCA_components = pd.DataFrame(pc,columns=['pc1','pc2','pc3','pc4','pc5','pc6','pc7','pc8','pc9','pc10','pc11','pc12','pc13'])

# %%
PCA_components.head()
# Out:
#         pc1       pc2       pc3       pc4       pc5       pc6       pc7  \
# 0  2.128505 -0.032230 -0.624261  1.812840  0.727034 -0.933961 -1.607021
# 1  2.333252  2.730205 -0.195366 -0.516460 -0.044128 -0.365189  0.354242
# 2  1.580931 -0.673557 -1.045646 -0.405110  0.073333 -0.758891  0.023657
# 3 -0.743016 -0.180342  0.490203 -1.088149  0.472176 -1.489093  0.577847
# 4  3.582825 -1.769509  7.253149 -0.256930 -0.674767  3.571901 -1.988466
#
#         pc8       pc9      pc10      pc11      pc12      pc13
# 0 -0.878979 -1.347900  0.692798  0.311966 -1.790873  0.647721
# 1 -1.939664  0.238409 -0.321844 -0.607305  0.767468 -1.657051
# 2  0.246334  1.736765 -0.141447 -0.676597  1.396010 -0.930295
# 3 -1.135749  1.574349 -0.161179 -0.659271 -0.007181  0.775329
# 4  1.071833  3.114783  0.655941 -0.874857 -0.590616  1.482291

# %%
plt.subplots(figsize=(10,10))
sns.heatmap(PCA_components.corr(),square=True,annot=True)

# %% [markdown]
# # PCA works great with multi colenearity and we can see multi colenearity is removed totally.

# %% [markdown]
# # Now we can start doing clustering by finding out optimal k value.

# %%
from sklearn.cluster import KMeans

# %%
cluster_range = range( 1, 15 )
cluster_errors = []
for num_clusters in cluster_range:
    clusters = KMeans( num_clusters,n_init = 15, random_state=2)
    clusters.fit(PCA_components)
    labels = clusters.labels_
    centroids = clusters.cluster_centers_
    cluster_errors.append( clusters.inertia_ )
clusters_df = pd.DataFrame( { "num_clusters":cluster_range, "cluster_errors": cluster_errors } )
clusters_df[0:15]
# Out:
#     num_clusters  cluster_errors
# 0              1     6788.370904
# 1              2     5841.698403
# 2              3     5293.709026
# 3              4     4969.754061
# 4              5     4660.673434
# 5              6     4376.552772
# 6              7     4118.650652
# 7              8     3952.208897
# 8              9     3756.044703
# 9             10     3664.794129
# 10            11     3531.765395
# 11            12     3431.255761
# 12            13     3346.379119
# 13            14     3238.898309

# %% [markdown]
# # There is great drop in cluster errors after 2. So 2 might be used as k value.

# %%
ks = range(1, 10)
inertias = []
for k in ks:
    # Create a KMeans instance with k clusters: model
    model = KMeans(n_clusters=k)
    
    # Fit model to samples
    model.fit(PCA_components.iloc[:,:3])
    
    # Append the inertia to the list of inertias
    inertias.append(model.inertia_)
    
plt.plot(ks, inertias, '-o', color='black')
plt.xlabel('number of clusters, k')
plt.ylabel('inertia')
plt.xticks(ks)
plt.show()

# %% [markdown]
# # From the elbow plot we can see two clusters are optimal.

# %%
kmeans = KMeans(n_clusters=2, n_init = 15, random_state=2)

# %%
kmeans.fit(PCA_components)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=2, n_init=15, n_jobs=None, precompute_distances='auto',
#        random_state=2, tol=0.0001, verbose=0)

# %%
centroids=kmeans.cluster_centers_

# %%
centroid_df = pd.DataFrame(centroids, columns = list(PCA_components) )
centroid_df
# Out:
#         pc1       pc2       pc3       pc4       pc5       pc6       pc7  \
# 0 -1.342793 -0.140489  0.147200 -0.102751  0.023293  0.133478 -0.061759
# 1  1.717526  0.179695 -0.188279  0.131425 -0.029793 -0.170727  0.078994
#
#         pc8       pc9      pc10      pc11      pc12      pc13
# 0 -0.075341 -0.029944  0.040684 -0.008823  0.035590 -0.035697
# 1  0.096366  0.038300 -0.052037  0.011286 -0.045522  0.045660

# %%
df_labels = pd.DataFrame(kmeans.labels_ , columns = list(['labels']))

df_labels['labels'] = df_labels['labels'].astype('category')

# %%
selection_df_labeled = PCA_components.join(df_labels)

# %%
selection_clusters = selection_df_labeled.groupby(['labels'])
#wine_clusters = wine_data_attr.groupby(['clusters'])
df0=selection_clusters.get_group(0)
df1=selection_clusters.get_group(1)
finaldf = pd.concat([df0,df1])
finaldf.head()
# Out:
#          pc1       pc2       pc3       pc4       pc5       pc6       pc7  \
# 3  -0.743016 -0.180342  0.490203 -1.088149  0.472176 -1.489093  0.577847
# 6  -1.587221  1.952652 -0.732433 -0.435190  0.498384  2.764193  0.355711
# 7  -0.987258 -0.108459  0.250366  0.277909  1.147191 -0.226020 -0.132209
# 10 -1.922949  0.584219  0.628402 -0.487867  0.301806  0.403469  0.463907
# 11 -0.684611  0.123374  0.443661 -1.639113  1.978864 -0.499985  1.037002
#
#          pc8       pc9      pc10      pc11      pc12      pc13 labels
# 3  -1.135749  1.574349 -0.161179 -0.659271 -0.007181  0.775329      0
# 6  -1.325687  0.588775 -0.377812  0.182452  0.147919 -0.547252      0
# 7   2.352294  0.136559  0.628544 -2.088945 -0.620189  0.689162      0
# 10 -1.040276 -0.079537 -0.184140 -1.196412  0.823422 -1.204759      0
# 11  0.018568  0.645108 -1.409737 -1.403482 -0.110536  1.237638      0

# %% [markdown]
# # The created labels can be used as target variable for our model.

# %%
final_data = pd.concat([df_labled,finaldf['labels']],axis=1)

# %%
final_data.head()
# Out:
#    Application_ID  Current City  Python (out of 3)  R Programming (out of 3)  \
# 0               0             4                  0                         2
# 1               1             4                  2                         0
# 2               2             4                  3                         0
# 3               3             4                  2                         0
# 4               4             4                  2                         0
#
#    Deep Learning (out of 3)  PHP (out of 3)  MySQL (out of 3)  \
# 0                         0               2                 0
# 1                         0               2                 2
# 2                         1               2                 2
# 3                         2               1                 0
# 4                         0               2                 0
#
#    HTML (out of 3)  CSS (out of 3)  JavaScript (out of 3)  AJAX (out of 3)  \
# ...

# %%
sns.pairplot(final_data.drop('Application_ID',axis=1),diag_kind='kde',hue='labels')
# Out:
# C:\Users\lenovo\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py:487: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# C:\Users\lenovo\Anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2

# %%
final_data.drop('Application_ID',axis=1).boxplot(by = 'labels', figsize=(15, 10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002374E4FC488>,
# ...
#       dtype=object)

# %% [markdown]
# # Comparing pairplot and boxplot we can see label 0 should be rejected and label 1 should be shortlisted for interview call letter.

# %% [markdown]
# # Since we are doing bivariate analysis predicting yes or no we can use classification techniques to predict the target variable.

# %%
from sklearn.linear_model import LogisticRegressionCV
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier,AdaBoostClassifier,GradientBoostingClassifier

# %%
x = final_data.drop(['Application_ID','labels'],axis=1)
y = final_data['labels']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.3,random_state=1)

# %%
array = [LogisticRegressionCV(),
        DecisionTreeClassifier(),
        RandomForestClassifier(n_estimators=50,n_jobs=5),
        AdaBoostClassifier(),
        GradientBoostingClassifier()]

# %%
for i in range (0,len(array)):
    array[i].fit(x_train,y_train)
# Out:
# C:\Users\lenovo\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:939: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html.
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\lenovo\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:939: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html.
# Please also refer to the documentation for alternative solver options:
# ...

# %%
from sklearn.metrics import accuracy_score,recall_score,precision_score,f1_score,classification_report

# %%
l=[]
for i in range (0,len(array)):
    y_pred=array[i].predict(x_test)
    l.append(accuracy_score(y_pred,y_test))
print(l)
# Out:
# [0.9830508474576272, 0.9576271186440678, 0.9915254237288136, 0.9830508474576272, 0.9830508474576272]

# %%
final = pd.DataFrame(l,index=('Logistic regreesion','Decision tree','Randomforest','Ada boost','Gradient boost'),columns=['Accuracy score'])
final
# Out:
#                      Accuracy score
# Logistic regreesion        0.983051
# Decision tree              0.957627
# Randomforest               0.991525
# Ada boost                  0.983051
# Gradient boost             0.983051

# %%
rf = RandomForestClassifier(n_estimators=50,n_jobs=5)

# %%
rf_model = rf.fit(x_train,y_train)
rf_model
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=50, n_jobs=5,
#                        oob_score=False, random_state=None, verbose=0,
#                        warm_start=False)

# %%
y_pred = rf.predict(x_test)

# %%
print(classification_report(y_pred,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.97      0.98        69
#            1       0.96      0.98      0.97        49
#
#     accuracy                           0.97       118
#    macro avg       0.97      0.98      0.97       118
# weighted avg       0.97      0.97      0.97       118

# %% [markdown]
# # Both the precision and recall score are high, which implies our model able to predict and detect perfectly.
